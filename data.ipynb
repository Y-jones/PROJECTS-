# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("SuperMarket Analysis.csv")

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Sales                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
total = df["Sales"].sum()
print(total)
# Out:
# 298462.41599999997

# %%
average = df["Sales"].mean()
print(average)
# Out:
# 298.46241599999996

# %%
max_line = df.groupby("Product line")["Sales"].sum()
print(max_line)
# Out:
# Product line
# Electronic accessories    64194.2175
# Fashion accessories       43328.2920
# Food and beverages        43277.8080
# Health and beauty         55203.8445
# Home and lifestyle        42061.7715
# Sports and travel         50396.4825
# Name: Sales, dtype: float64

# %%
max_line = df.groupby("Product line")["Sales"].sum().idxmax()
print(max_line)
# Out:
# Electronic accessories

# %%
max_line = df.groupby("Product line")["Quantity"].sum()
print(max_line)
# Out:
# Product line
# Electronic accessories    1038
# Fashion accessories        805
# Food and beverages         916
# Health and beauty          983
# Home and lifestyle         832
# Sports and travel          837
# Name: Quantity, dtype: int64

# %%
max_line = df.groupby("Product line")["Quantity"].sum().idxmax()
print(max_line)
# Out:
# Electronic accessories

# %%
max_line = df.groupby("Branch")["Sales"].sum()
print(max_line)
# Out:
# Branch
# A    107049.558
# B     94243.590
# C     97169.268
# Name: Sales, dtype: float64

# %%
max_line = df.groupby("Branch")["Sales"].sum().idxmax()
print(max_line)
# Out:
# A

# %%
max_line = df.groupby("Customer type")["Sales"].sum()
print(max_line)
# Out:
# Customer type
# Member    148329.699
# Normal    150132.717
# Name: Sales, dtype: float64

# %%
max_line = df.groupby("Customer type")["Sales"].sum().idxmax()
print(max_line)
# Out:
# Normal

# %%
max_line = df.groupby("Payment")["Sales"].sum()
print(max_line)
# Out:
# Payment
# Cash           109728.5910
# Credit card     91750.2495
# Ewallet         96983.5755
# Name: Sales, dtype: float64

# %%
max_line = df.groupby("Payment")["Sales"].sum().idxmax()
print(max_line)
# Out:
# Cash

# %%
max_line = df.groupby("Gender")["Sales"].sum()
print(max_line)
# Out:
# Gender
# Female    154917.483
# Male      143544.933
# Name: Sales, dtype: float64

# %%
max_line = df.groupby("Gender")["Sales"].sum().idxmax()
print(max_line)
# Out:
# Female

# %%
max_month = df.groupby("Date")["Sales"].sum().idxmax() 
print(max_month)
# Out:
# 3/2/2019

# %%
df.plot(x="Quantity", y="Sales", kind="line")
# Out:
# <Axes: xlabel='Quantity'>

# %%
df.plot(x="Quantity", y="Sales", kind="scatter")
# Out:
# <Axes: xlabel='Quantity', ylabel='Sales'>

# %%
df.plot(x="Quantity", y="Sales", kind="bar")
# Out:
# <Axes: xlabel='Quantity'>

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(10, 8))
sns.heatmap(
    corr, 
    annot=True,      
    cmap="coolwarm",
    fmt=".2f",       
    vmin=-1, vmax=1, 
    linewidths=0.5   
)

plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x=df["Sales"])
plt.title("Box Plot")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df["Quantity"])
plt.title("Box Plot")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df["Unit price"])
plt.title("Box Plot")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df["cogs"])
plt.title("Box Plot")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df["gross income"])
plt.title("Box Plot")
plt.show()

# %%
df.plot(x="Quantity", y="Sales", kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x="Unit price", y="Sales", kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x="Sales", y="gross income", kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x="Tax 5%", y="Sales", kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x="Quantity", y="Sales", kind="line")
# Out:
# <Axes: xlabel='Quantity'>

# %%
df.plot(x="Quantity", y="Sales", kind="scatter")
# Out:
# <Axes: xlabel='Quantity', ylabel='Sales'>
